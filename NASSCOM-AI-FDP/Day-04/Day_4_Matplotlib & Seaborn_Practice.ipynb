# %% [markdown]
# <a href="https://colab.research.google.com/github/jagadeeshdandu/NASSCOM-AI-FDP/blob/main/Day_4_Matplotlib%20%26%20Seaborn_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -----------------------------------------------------------
# 🧳 PRACTICAL: Getting Started with matplotlib Library
# -----------------------------------------------------------

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
# -----------------------------------------------------------
# 🔹 1. LINE PLOT
# -----------------------------------------------------------

# Create a simple line plot for sin(x)
x = np.linspace(0, 15, 100)
y = np.sin(x)

plt.figure(figsize=(8, 4))
plt.plot(x, y, label='sin(x)', color='blue', linewidth=2)
plt.title('Line Plot of sin(x)')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.grid(True)
plt.legend()
plt.show()

# %%
# -----------------------------------------------------------
# 🔹 2. BAR CHART
# -----------------------------------------------------------

# Simple bar chart with categories and values
categories = ['A', 'B', 'C', 'D']
values = [67, 45, 56, 30]

plt.figure(figsize=(6, 4))
plt.bar(categories, values, color='orange')
plt.title('Bar Chart Example')
plt.xlabel('Category')
plt.ylabel('Value')
plt.show()

# %%
# -----------------------------------------------------------
# 🔹 3. HORIZONTAL BAR CHART
# -----------------------------------------------------------

# Display the same bar chart horizontally
plt.figure(figsize=(6, 4))
plt.barh(categories, values, color='green')
plt.title('Horizontal Bar Chart')
plt.xlabel('Value')
plt.ylabel('Category')
plt.show()

# %%
# -----------------------------------------------------------
# 🔹 4. SCATTER PLOT
# -----------------------------------------------------------

# Scatter plot to show relationship with noise
np.random.seed(42)
x = np.random.rand(50)
y = x + np.random.normal(0, 0.5, 50)

plt.figure(figsize=(6, 4))
plt.scatter(x, y, color='purple')
plt.title('Scatter Plot Example')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid(True)
plt.show()

# %%
# -----------------------------------------------------------
# 🔹 5. HISTOGRAM
# -----------------------------------------------------------

# Histogram to show distribution of random data
data = np.random.randn(1000)

plt.figure(figsize=(6, 4))
plt.hist(data, bins=30, color='skyblue', edgecolor='black')
plt.title('Histogram of Normally Distributed Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
# -----------------------------------------------------------
# 🔹 6. PIE CHART
# -----------------------------------------------------------

# Pie chart to show proportions of fruit types
sizes = [30, 40, 15, 15]
labels = ['Apple', 'Banana', 'Mango', 'Grapes']
colors = ['red', 'yellow', 'orange', 'purple']

plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart of Fruits')
plt.axis('equal')
plt.show()

# %%
# -----------------------------------------------------------
# 🔹 7. MULTIPLE PLOTS IN ONE FIGURE
# -----------------------------------------------------------

# Plotting sin(x) and cos(x) in a single figure
x = np.linspace(0, 2 * np.pi, 400)
y1 = np.sin(x)
y2 = np.cos(x)

plt.figure(figsize=(10, 5))
plt.plot(x, y1, label='sin(x)', color='blue')
plt.plot(x, y2, label='cos(x)', color='green')
plt.title('Sin and Cos Functions')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %%
# -----------------------------------------------------------
# 🔹 8. SUBPLOTS
# -----------------------------------------------------------

# Using subplots to display multiple charts in one window
fig, axs = plt.subplots(1, 2, figsize=(10, 4))
axs[0].plot(x, y1, 'tab:blue')
axs[0].set_title('sin(x)')
axs[1].plot(x, y2, 'tab:green')
axs[1].set_title('cos(x)')
plt.suptitle('Subplot Example')
plt.show()

# %%
# -----------------------------------------------------------
# 🔹 9. BOX PLOT
# -----------------------------------------------------------

# Box plot to visualize the spread and outliers in data
np.random.seed(5)
data = np.random.normal(100, 20, 200)

plt.figure(figsize=(6, 4))
plt.boxplot(data, vert=True)
plt.title('Box Plot Example')
plt.ylabel('Values')
plt.grid(True)
plt.show()

# %%
# -----------------------------------------------------------
# 🔹 10. AREA PLOT
# -----------------------------------------------------------

# Area plot to show stacked values over time
days = np.arange(1, 8)
water = [2, 3, 4, 3, 5, 6, 7]
milk = [1, 2, 1, 2, 3, 4, 3]

plt.figure(figsize=(8, 4))
plt.stackplot(days, water, milk, labels=['Water', 'Milk'], colors=['blue', 'lightgreen'])
plt.title('Area Plot of Liquid Consumption')
plt.xlabel('Day')
plt.ylabel('Litres')
plt.legend()
plt.show()

# %%
# -----------------------------------------------------------
# 🔹 11. ERROR BAR PLOT
# -----------------------------------------------------------

# Error bar plot to show uncertainty in measurements
x = np.arange(0.1, 4, 0.5)
y = np.exp(-x)
error = 0.1 + 0.2 * x

plt.figure(figsize=(6, 4))
plt.errorbar(x, y, yerr=error, fmt='-o', ecolor='red', capsize=5)
plt.title('Error Bar Plot')
plt.xlabel('X')
plt.ylabel('Y = exp(-x)')
plt.grid(True)
plt.show()

# %%
# -----------------------------------------------------------
# 🔹 12. CATEGORICAL PLOTS (COUNT PLOT & GROUPED BAR)
# -----------------------------------------------------------

# Create a synthetic DataFrame with categorical data
category_data = pd.DataFrame({
    'Department': ['HR', 'IT', 'HR', 'Sales', 'Sales', 'IT', 'IT', 'HR', 'Sales', 'IT'],
    'Satisfaction': [3, 4, 2, 5, 4, 3, 4, 2, 5, 4]
})

# Count plot equivalent: Bar chart of value counts
dept_counts = category_data['Department'].value_counts()
plt.figure(figsize=(6, 4))
plt.bar(dept_counts.index, dept_counts.values, color='coral')
plt.title('Count of Employees by Department')
plt.xlabel('Department')
plt.ylabel('Count')
plt.show()

# %%
# Grouped bar plot for categorical data
mean_satisfaction = category_data.groupby('Department')['Satisfaction'].mean()
plt.figure(figsize=(6, 4))
plt.bar(mean_satisfaction.index, mean_satisfaction.values, color='teal')
plt.title('Average Satisfaction by Department')
plt.xlabel('Department')
plt.ylabel('Average Satisfaction')
plt.show()

# %%
summary_data = {
    'Function': [
        'plt.plot()',
        'plt.bar()',
        'plt.barh()',
        'plt.scatter()',
        'plt.hist()',
        'plt.pie()',
        'plt.subplot()',
        'plt.subplots()',
        'plt.boxplot()',
        'plt.stackplot()',
        'plt.errorbar()',
        'plt.legend()',
        'plt.title()',
        'plt.xlabel()',
        'plt.ylabel()',
        'plt.grid()',
        'plt.show()'
    ],
    'Use Case': [
        'Line chart for continuous data',
        'Vertical bar chart',
        'Horizontal bar chart',
        'Scatter plot for relation between variables',
        'Histogram for distribution analysis',
        'Pie chart for categorical proportions',
        'Single subplot in a grid',
        'Multiple subplots layout',
        'Box plot for statistical summary (median, IQR)',
        'Area plot for stacked values',
        'Error bars to show confidence/uncertainty',
        'Add legend to a plot',
        'Set title of the plot',
        'Set label for X-axis',
        'Set label for Y-axis',
        'Enable gridlines',
        'Display the plot'
    ]
}

summary_df = pd.DataFrame(summary_data)
print("\n\n📌 Summary of Common matplotlib Functions:\n")
display(summary_df)

# -----------------------------------------------------------
# 🔹 END OF MATPLOTLIB PRACTICAL
# -----------------------------------------------------------
# Out:
# 📌 Summary of Common matplotlib Functions:
#            Function                                        Use Case
# 0        plt.plot()                  Line chart for continuous data
# 1         plt.bar()                              Vertical bar chart
# 2        plt.barh()                            Horizontal bar chart
# 3     plt.scatter()     Scatter plot for relation between variables
# 4        plt.hist()             Histogram for distribution analysis
# 5         plt.pie()           Pie chart for categorical proportions
# 6     plt.subplot()                        Single subplot in a grid
# 7    plt.subplots()                        Multiple subplots layout
# 8     plt.boxplot()  Box plot for statistical summary (median, IQR)
# 9   plt.stackplot()                    Area plot for stacked values
# 10   plt.errorbar()       Error bars to show confidence/uncertainty
# 11     plt.legend()                            Add legend to a plot
# 12      plt.title()                           Set title of the plot
# 13     plt.xlabel()                            Set label for X-axis
# 14     plt.ylabel()                            Set label for Y-axis
# 15       plt.grid()                                Enable gridlines
# 16       plt.show()                                Display the plot

# %%
# -----------------------------------------------------------
# 📚 PRACTICAL: Getting Started with Seaborn Library
# -----------------------------------------------------------

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Set seaborn theme
sns.set_theme(style="darkgrid")

# %%
# -----------------------------------------------------------
# 🔹 1. LOAD BUILT-IN DATASET
# -----------------------------------------------------------

# Load built-in "tips" dataset for demonstration
tips = sns.load_dataset("tips")
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# -----------------------------------------------------------
# 🔹 2. SCATTER PLOT WITH HUE
# -----------------------------------------------------------

sns.scatterplot(data=tips, x="total_bill", y="tip", hue="smoker")
plt.title("Tip vs Total Bill by Smoker Status")
plt.show()

# %%
# -----------------------------------------------------------
# 🔹 3. BAR PLOT (Categorical)
# -----------------------------------------------------------

sns.barplot(data=tips, x="day", y="tip", ci="sd", palette="muted")
plt.title("Average Tip by Day")
plt.show()
# Out:
# /tmp/ipykernel_741/2928112283.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=tips, x="day", y="tip", ci="sd", palette="muted")
# /tmp/ipykernel_741/2928112283.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=tips, x="day", y="tip", ci="sd", palette="muted")

# %%
# -----------------------------------------------------------
# 🔹 4. BOXPLOT
# -----------------------------------------------------------

sns.boxplot(data=tips, x="day", y="tip", hue="sex")
plt.title("Boxplot of Tips by Day and Gender")
plt.show()

# %%
# -----------------------------------------------------------
# 🔹 5. VIOLIN PLOT
# -----------------------------------------------------------

sns.violinplot(data=tips, x="day", y="tip", hue="sex", split=True)
plt.title("Violin Plot of Tips by Day and Gender")
plt.show()

# %%
# -----------------------------------------------------------
# 🔹 6. HEATMAP (CORRELATION MATRIX)
# -----------------------------------------------------------

corr = tips.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
# -----------------------------------------------------------
# 🔹 7. PAIRPLOT
# -----------------------------------------------------------

sns.pairplot(tips, hue="sex")
plt.suptitle("Pairplot of Tips Dataset", y=1.02)
plt.show()

# %%
# -----------------------------------------------------------
# 🔹 8. COUNT PLOT (CATEGORICAL COUNTS)
# -----------------------------------------------------------

sns.countplot(data=tips, x="day", hue="sex")
plt.title("Count of Customers per Day by Gender")
plt.show()

# %%
# -----------------------------------------------------------
# 🔹 9. GEOGRAPHICAL PLOT (USING sample COORDINATES)
# -----------------------------------------------------------

data = pd.DataFrame({
    "city": ["CityA", "CityB", "CityC", "CityD"],
    "latitude": [28.6, 19.1, 13.0, 22.6],
    "longitude": [77.2, 72.8, 80.2, 88.3],
    "sales": [150, 200, 130, 170]
})

plt.figure(figsize=(8, 5))
sns.scatterplot(data=data, x="longitude", y="latitude", size="sales", hue="city", legend="full", sizes=(50, 300))
plt.title("Geographic Sales Distribution (Simulated)")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.grid(True)
plt.show()

# %%
# -----------------------------------------------------------
# 🔹 10. DISTRIBUTION PLOT
# -----------------------------------------------------------

sns.histplot(data=tips, x="total_bill", kde=True)
plt.title("Distribution of Total Bill")
plt.show()

# %%
# -----------------------------------------------------------
# 🔹 11. STRIP PLOT
# -----------------------------------------------------------

sns.stripplot(data=tips, x="day", y="tip", jitter=True, hue="sex")
plt.title("Strip Plot of Tips by Day and Gender")
plt.legend(loc='best')
plt.show()

# %%
# -----------------------------------------------------------
# 🔹 12. SWARM PLOT
# -----------------------------------------------------------

sns.swarmplot(data=tips, x="day", y="total_bill", hue="sex")
plt.title("Swarm Plot of Total Bill by Day and Gender")
plt.show()

# %%
# -----------------------------------------------------------
# 🔹 13. LINEPLOT
# -----------------------------------------------------------

# Group data for daily average tip
avg_tips = tips.groupby("day")["tip"].mean().reset_index()
sns.lineplot(data=avg_tips, x="day", y="tip")
plt.title("Line Plot of Average Tips by Day")
plt.show()
# Out:
# /tmp/ipykernel_741/1447707521.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_tips = tips.groupby("day")["tip"].mean().reset_index()

# %%
# -----------------------------------------------------------
# 📚 PRACTICAL: Text data visualization
# -----------------------------------------------------------

from wordcloud import WordCloud
from collections import Counter


# -----------------------------------------------------------
# 🔹 14. TEXT ANALYSIS: WORD FREQUENCY PLOT
# -----------------------------------------------------------

# Simulate a list of review texts
review_texts = [
    "Great food and great service",
    "Food was amazing, especially the dessert",
    "Service was slow but food was good",
    "The ambiance was perfect",
    "Not happy with service but liked the food",
    "Dessert and coffee were excellent"
]

# Combine all reviews into one string
all_words = " ".join(review_texts).lower().split()
word_counts = Counter(all_words)

# Create a DataFrame from the word counts
word_freq_df = pd.DataFrame(word_counts.items(), columns=['word', 'frequency'])

# %%
# Bar plot of most common words
plt.figure(figsize=(10, 5))
sns.barplot(data=word_freq_df.sort_values(by="frequency", ascending=False), x="word", y="frequency", palette="viridis")
plt.title("Word Frequency in Customer Reviews")
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_741/2792827115.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=word_freq_df.sort_values(by="frequency", ascending=False), x="word", y="frequency", palette="viridis")

# %%
# -----------------------------------------------------------
# 🔹 15. WORDCLOUD VISUALIZATION
# -----------------------------------------------------------

# Create and display a word cloud
wordcloud = WordCloud(width=500, height=300, background_color='white').generate(" ".join(all_words))

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Word Cloud of Customer Feedback")
plt.show()

# %%
# -----------------------------------------------------------
# 🔹 SUMMARY OF KEY SEABORN FUNCTIONS
# -----------------------------------------------------------

summary_data = {
    "Function": [
        "sns.scatterplot()",
        "sns.barplot()",
        "sns.boxplot()",
        "sns.violinplot()",
        "sns.heatmap()",
        "sns.pairplot()",
        "sns.countplot()",
        "sns.histplot()",
        "sns.stripplot()",
        "sns.swarmplot()",
        "sns.lineplot()",
        "wordcloud.WordCloud()"
    ],
    "Use Case": [
        "Scatter plot with semantic mapping",
        "Bar chart for aggregated values",
        "Box plot for distribution and outliers",
        "Violin plot for density + boxplot",
        "Heatmap for correlations/matrices",
        "Pairwise relationship visualization",
        "Count plot for categorical variables",
        "Histogram with KDE for distributions",
        "Strip plot for spread of categorical values",
        "Swarm plot for precise dot positioning",
        "Line chart for trends over categories",
        "Generate word cloud for text data"
    ]
}

summary_df = pd.DataFrame(summary_data)
print("\n\n📌 Summary of Seaborn and Text Visualization Functions:")
display(summary_df)
# Out:
# 📌 Summary of Seaborn and Text Visualization Functions:
#                  Function                                     Use Case
# 0       sns.scatterplot()           Scatter plot with semantic mapping
# 1           sns.barplot()              Bar chart for aggregated values
# 2           sns.boxplot()       Box plot for distribution and outliers
# 3        sns.violinplot()            Violin plot for density + boxplot
# 4           sns.heatmap()            Heatmap for correlations/matrices
# 5          sns.pairplot()          Pairwise relationship visualization
# 6         sns.countplot()         Count plot for categorical variables
# 7          sns.histplot()         Histogram with KDE for distributions
# 8         sns.stripplot()  Strip plot for spread of categorical values
# 9         sns.swarmplot()       Swarm plot for precise dot positioning
# 10         sns.lineplot()        Line chart for trends over categories
# 11  wordcloud.WordCloud()            Generate word cloud for text data
